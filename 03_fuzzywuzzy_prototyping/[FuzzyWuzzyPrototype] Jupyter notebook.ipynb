# %% [markdown]
# # [FuzzyWuzzyProto] Jupyter notebook

# %% [markdown]
# # The problem :

# %% [markdown]
# A list of names has been generated from our database, where although the IDs match for each row, the names do not match.
# This is due to a variety of factors, such as illegal characters or the names being in reverse order, or in some cases an email address appearing in the name field.
# The purpose of this notebook is to try and improve the similarity of the match using both data cleaning steps in python and fuzzy matching.
#
# Note: This notebook has been updated to use the Room Type Data from Kaggle, as the original matching exercise contained personally identifiable information. Thanks to the team who assembled and provided the data for use.
# https://www.kaggle.com/leandrodoze/room-type

# %% [markdown]
# # The packages :

# %% [markdown]
# First things first, let's import `Pandas` :

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# If you don't have `FuzzyWuzzy` installed, you can install it by running `pip install fuzzywuzzy[speedup]` inside your Jupyter notebook or from the PIP or Anaconda prompt. If this doesn't work, you should install `FuzzyWuzzy` like this: `pip install fuzzywuzzy` and then install `python-levenshtein` like this: `pip install python-Levenshtein` (in order to speed the matching process).
#
# From `FuzzyWuzzy`, we'll mainly need two modules: `process` and `fuzz` :

# %%
from fuzzywuzzy import process, fuzz

# %% [markdown]
# Let's also import `matplotlib` for data visualization and also some modules to improve readability of the notebook:

# %%
import matplotlib.pyplot as plt
from IPython.display import HTML, display, Math, Latex, Image
HTML('''<script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-MML-AM_CHTML' async></script>''')
# Out:
# <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-MML-AM_CHTML' async></script>

# %% [markdown]
#  And for good measure, let's add some CSS to style our dataframes for added contrast between the axes and the data itself (If you don't like this style, just delete the cell, restart the kernel and re-run all cells). <br>
# <sub id='codex'>[code explanation 1](#codex1)</sub>
# <a id='code1'></a>

# %%
# %%HTML
# <style>.dataframe th, td:first-child{background:#3f577c;font-family:monospace;color:white;border:3px solid white;
# text-align:left !important;}#codex{float:right;}</style>
# Out:
# <style>.dataframe th, td:first-child{background:#3f577c;font-family:monospace;color:white;border:3px solid white;
# text-align:left !important;}#codex{float:right;}</style>

# %% [markdown]
# This next bit just insures the custom CSS style we just applied stays on when we use `style.background_gradient` later on:

# %%
th_props = [('background','#3f577c'), ('font-family','monospace'), ('color','white'),('border','3px solid white'),
            ('text-align','left !important')]
styles = [dict(selector="th", props=th_props)]

# %% [markdown]
# # The data :

# %% [markdown]
# We have two dataframes or tables we'll need to match here :
# * `example_name_data_a` that contains first name and last name data for one group of students;
# * `example_name_data_b` that contains first name and last name data for another group of students;

# %%
a_df = pd.read_csv('data/example_name_data_a.csv', encoding='unicode_escape')
b_df = pd.read_csv('data/example_name_data_b.csv', encoding='unicode_escape')
display( a_df.head(10) )
display( b_df.head(10) )
# Out:
#       SFDC_ACCOUNT_ID                                     name_a
# 0  0012400000qIKr5AAG                    Deluxe Room, 1 King Bed
# 1  0012400000qJfleAAC      Standard Room, 1 King Bed, Accessible
# 2  0012400000qJfp2AAC         Grand Corner King Room, 1 King Bed
# 3  0012400000vZcUxAAK                 Suite, 1 King Bed (Parlor)
# 4  0011p00001YEVvfAAH        High-Floor Premium Room, 1 King Bed
# 5  0012400001Ko0VnAAJ     Traditional Double Room, 2 Double Beds
# 6  0012400000J4kLeAAJ               Room, 1 King Bed, Accessible
# 7  0011p00001anUF3AAM                    Deluxe Room, 1 King Bed
# 8  0011p00001Ti4LkAAJ                                Deluxe Room
# 9  0014H000021UEyqQAG  Room, 2 Double Beds (19th to 25th Floors)
#       SFDC_ACCOUNT_ID                                             name_b
# 0  0012400000qIKr5AAG                                   Deluxe King Room
# 1  0012400000qJfleAAC            Standard King Roll-in Shower Accessible
# 2  0012400000qJfp2AAC                             Grand Corner King Room
# 3  0012400000vZcUxAAK                                  King Parlor Suite
# 4  0011p00001YEVvfAAH                       High-Floor Premium King Room
# 5  0012400001Ko0VnAAJ                   Double Room with Two Double Beds
# 6  0012400000J4kLeAAJ                      King Room - Disability Access
# 7  0011p00001anUF3AAM                                   Deluxe King Room
# 8  0011p00001Ti4LkAAJ                       Deluxe Room (Non Refundable)
# 9  0014H000021UEyqQAG  Two Double Beds - Location Room (19th to 25th ...

# %% [markdown]
# ---
#
# # Data Cleaning :

# %% [markdown]
# Before using `FuzzyWuzzy`, we need to clean our data frames.
# The idea is to :
#
# 1. Remove illegal characters or incorrect values

# %%
REQUIRED_FIELDS_a = ['name_a']
REQUIRED_FIELDS_b = ['name_b']

# %%
a_test_df = a_df
a_test_df.fillna('', inplace=True)
b_test_df = b_df
b_test_df.fillna('', inplace=True)
display( a_test_df.head(10) )
display( b_test_df.head(10) )
# Out:
#       SFDC_ACCOUNT_ID                                     name_a
# 0  0012400000qIKr5AAG                    Deluxe Room, 1 King Bed
# 1  0012400000qJfleAAC      Standard Room, 1 King Bed, Accessible
# 2  0012400000qJfp2AAC         Grand Corner King Room, 1 King Bed
# 3  0012400000vZcUxAAK                 Suite, 1 King Bed (Parlor)
# 4  0011p00001YEVvfAAH        High-Floor Premium Room, 1 King Bed
# 5  0012400001Ko0VnAAJ     Traditional Double Room, 2 Double Beds
# 6  0012400000J4kLeAAJ               Room, 1 King Bed, Accessible
# 7  0011p00001anUF3AAM                    Deluxe Room, 1 King Bed
# 8  0011p00001Ti4LkAAJ                                Deluxe Room
# 9  0014H000021UEyqQAG  Room, 2 Double Beds (19th to 25th Floors)
#       SFDC_ACCOUNT_ID                                             name_b
# 0  0012400000qIKr5AAG                                   Deluxe King Room
# 1  0012400000qJfleAAC            Standard King Roll-in Shower Accessible
# 2  0012400000qJfp2AAC                             Grand Corner King Room
# 3  0012400000vZcUxAAK                                  King Parlor Suite
# 4  0011p00001YEVvfAAH                       High-Floor Premium King Room
# 5  0012400001Ko0VnAAJ                   Double Room with Two Double Beds
# 6  0012400000J4kLeAAJ                      King Room - Disability Access
# 7  0011p00001anUF3AAM                                   Deluxe King Room
# 8  0011p00001Ti4LkAAJ                       Deluxe Room (Non Refundable)
# 9  0014H000021UEyqQAG  Two Double Beds - Location Room (19th to 25th ...

# %%
a_test_df = a_test_df.replace(to_replace=r'(\#)|(\?+)|(UNKNOWN)|(unknown)|(student)|(STUDENT)', value='', regex=True)
a_test_df = a_test_df.replace(to_replace=r'(\s\-)|(\s\.)|(\.\s)|(\,\s)|(\s\.\s)|(\-\s)|(\s\-)|(\s\:)|(\s\_)|(\:)|(\.)|(\_)|(\/)|(\-)|(\")|(\,)|(\s{2,})', value=' ', regex=True)
#print(clean_field)
#print(pd.Series(test_df[clean_field]))
display( a_test_df.head(10) )
# Out:
#       SFDC_ACCOUNT_ID                                    name_a
# 0  0012400000qIKr5AAG                    Deluxe Room 1 King Bed
# 1  0012400000qJfleAAC       Standard Room 1 King Bed Accessible
# 2  0012400000qJfp2AAC         Grand Corner King Room 1 King Bed
# 3  0012400000vZcUxAAK                 Suite 1 King Bed (Parlor)
# 4  0011p00001YEVvfAAH        High Floor Premium Room 1 King Bed
# 5  0012400001Ko0VnAAJ     Traditional Double Room 2 Double Beds
# 6  0012400000J4kLeAAJ                Room 1 King Bed Accessible
# 7  0011p00001anUF3AAM                    Deluxe Room 1 King Bed
# 8  0011p00001Ti4LkAAJ                               Deluxe Room
# 9  0014H000021UEyqQAG  Room 2 Double Beds (19th to 25th Floors)

# %%
b_test_df = b_test_df.replace(to_replace=r'(\#)|(\?+)|(UNKNOWN)|(unknown)|(student)|(STUDENT)', value='', regex=True)
b_test_df = b_test_df.replace(to_replace=r'(\s\-)|(\s\.)|(\.\s)|(\,\s)|(\s\.\s)|(\-\s)|(\s\-)|(\s\:)|(\s\_)|(\:)|(\.)|(\_)|(\/)|(\-)|(\")|(\,)|(\s{2,})', value=' ', regex=True)
#print(clean_field)
#print(pd.Series(test_df[clean_field]))
display( b_test_df.head(10) )
# Out:
#       SFDC_ACCOUNT_ID                                             name_b
# 0  0012400000qIKr5AAG                                   Deluxe King Room
# 1  0012400000qJfleAAC            Standard King Roll in Shower Accessible
# 2  0012400000qJfp2AAC                             Grand Corner King Room
# 3  0012400000vZcUxAAK                                  King Parlor Suite
# 4  0011p00001YEVvfAAH                       High Floor Premium King Room
# 5  0012400001Ko0VnAAJ                   Double Room with Two Double Beds
# 6  0012400000J4kLeAAJ                       King Room  Disability Access
# 7  0011p00001anUF3AAM                                   Deluxe King Room
# 8  0011p00001Ti4LkAAJ                       Deluxe Room (Non Refundable)
# 9  0014H000021UEyqQAG  Two Double Beds  Location Room (19th to 25th F...

# %%
for clean_field in REQUIRED_FIELDS_a:
    #clean_field = clean_field.strip().replace(' ', '').lower()
    a_test_df[clean_field] = a_test_df[clean_field].str.strip().str.lower()

# %%
for clean_field in REQUIRED_FIELDS_b:
    #clean_field = clean_field.strip().replace(' ', '').lower()
    b_test_df[clean_field] = b_test_df[clean_field].str.strip().str.lower()

# %%
#drop rows where the matching field is empty after cleaning
#a_test_df.drop(a_test_df[a_test_df['name_a'] == ''].index, inplace=True)
#b_test_df.drop(b_test_df[b_test_df['name_b'] == ''].index, inplace=True)

# %%
#a_test_df = a_test_df.sort_values(by=['name_a']).reset_index(drop=True)
#b_test_df = b_test_df.sort_values(by=['name_b']).reset_index(drop=True)
display( a_test_df.head(3) )
display( b_test_df.head(3) )
# Out:
#       SFDC_ACCOUNT_ID                               name_a
# 0  0012400000qIKr5AAG               deluxe room 1 king bed
# 1  0012400000qJfleAAC  standard room 1 king bed accessible
# 2  0012400000qJfp2AAC    grand corner king room 1 king bed
#       SFDC_ACCOUNT_ID                                   name_b
# 0  0012400000qIKr5AAG                         deluxe king room
# 1  0012400000qJfleAAC  standard king roll in shower accessible
# 2  0012400000qJfp2AAC                   grand corner king room

# %% [markdown]
# # What is the FuzzyWuzzy Package? :

# %% [markdown]
# The `FuzzyWuzzy` package compares two strings A and B and outputs a ratio that estimates the Levenshtein distance between them. The Levenshtein distance, which is the distance between A and B in terms of how many changes we have to make to the string A in order to transform it into string B. The changes include removing, adding or substituting characters. The fewer the changes we have to make, the more similar A and B are, which results in a higher ratio.
#
# As part of this prototype, I have been comparing multiple methods taken from articles to investigate different methods which could be productionised.

# %% [markdown]
# # FuzzyWuzzy application :

# %% [markdown]
# ### Method 1:
# Pairs of names given a specific column in each file
#
# #### Problem: not productionised as a function!
#
# #### Example: </br>
# * Row 30 from both files:
# * abdallah allidawi
# * abdullah alliddawi
# * ratio = 91

# %%
#Row 30 from both files - simple 1 letter difference
print(a_test_df['name_a'][30])
print(b_test_df['name_b'][30])
print ('ratio =' , fuzz.ratio(a_test_df['name_a'][30],b_test_df['name_b'][30]))
# Out:
# executive room 1 king bed non smoking
# executive king room
# ratio = 61

# %% [markdown]
# #### Method 2:
# * Create tuples as a series, and then process all match possibilities from both files
# * https://www.semicolonworld.com/question/58508/apply-fuzzy-matching-across-a-dataframe-column-and-save-results-in-a-new-column
#
# #### Problem 1: Really low performance
# #### Problem 2: Duplicates create a problem
# * 'ValueError: Index contains duplicate entries, cannot reshape'

# %%
compare = pd.MultiIndex.from_product([a_test_df['name_a'],
                                      b_test_df['name_b']]).to_series()

# %%
def metrics(tup):
    return pd.Series([fuzz.ratio(*tup),
                      fuzz.token_sort_ratio(*tup)],
                     ['ratio', 'token'])

# %%
compare.apply(metrics)

# %%
compare.apply(metrics).unstack().idxmax().unstack(0)

# %%
compare.apply(metrics).unstack(0).idxmax().unstack(0)

# %% [markdown]
# ### Method 3:
# * Create a function using process.extract
# * Based on: https://medium.com/analytics-vidhya/matching-messy-pandas-columns-with-fuzzywuzzy-4adda6c7994f
# * and https://github.com/kelmouloudi/MediumArticle-FuzzyWuzzy
#
# #### Problem: AGAIN low performance
# * Work fine for two files with 100 rows
# * Works slowly for two files with 5k rows!

# %%
a_test_df = a_test_df.sort_values(by=['name_a']).reset_index(drop=True)
b_test_df = b_test_df.sort_values(by=['name_b']).reset_index(drop=True)
# ideal to sort first for this function, performs better
# index must be correct for both to work properly

match_b = []
similarity = []

for i in a_test_df.name_a:
        ratio = process.extract( i, b_test_df.name_b, limit=1)
        match_b.append(ratio[0][0])
        similarity.append(ratio[0][1])

a_test_df['match_b'] = pd.Series(match_b)
a_test_df['similarity'] = pd.Series(similarity)

a_test_df.head(10)
# Out:
#       SFDC_ACCOUNT_ID                                             name_a  \
# 0  0012400000l6u0AAAQ                 business double room 2 double beds
# 1  0012400000jqfYCAAY                           business plan 1 king bed
# 2  00124000019HHXlAAO                                city room city view
# 3  0014H00002GHEvcQAH                            classic room 1 king bed
# 4  00124000008FHqrAAG                               club room 1 king bed
# 5  0011p00002JYCDNAA5                               club room 1 king bed
# 6  0011p0000265zAlAAI                    club room 1 king bed oceanfront
# 7  0012400001HOFKEAA5                             club room 2 queen beds
# 8  0011p00001dvdacAAA                             club room 2 queen beds
# 9  0012400000bjZrqAAE  club room city view (club lounge access for 2 ...
#
#                                              match_b  similarity
# 0          business double room with two double beds          91
# 1  accessible club ocean view suite with one king...          86
# 2                          queen room with city view          95
# 3                                  classic king room          95
# 4  accessible club ocean view suite with one king...          86
# 5  accessible club ocean view suite with one king...          86
# 6  accessible club ocean view suite with one king...          86
# 7  accessible club ocean view suite with one king...          86
# 8  accessible club ocean view suite with one king...          86
# 9                                 business king room          86

# %% [markdown]
# Now simplify this dataframe by only keeping the name and and `similarity` columns. Let's call it `final_result` :

# %%
# Results Table: 100% similarity
final_result_100 = a_test_df[a_test_df.similarity==100]
final_result_100 = final_result_100.sort_values(by=['SFDC_ACCOUNT_ID']).reset_index(drop=True)
final_result_100

## TODO ##
# Add a 'Match_Type' column which indicates these are "definite" matches
# Out:
#       SFDC_ACCOUNT_ID                      name_a                     match_b  \
# 0  0012400001Ime60AAB  regency club mountain view  regency club mountain view
# 1  0012400001Ime94AAB     regency club ocean view     regency club ocean view
# 2  0014H000021VWCKQA4                deluxe suite                deluxe suite
#
#    similarity
# 0         100
# 1         100
# 2         100

# %%
# Results Table: 90-99% similarity

final_result_90 = a_test_df[(a_test_df.similarity < 100) & (a_test_df.similarity > 89)]
final_result_90 = final_result_90.sort_values(by=['similarity','SFDC_ACCOUNT_ID']).reset_index(drop=True)
final_result_90

## TODO ##
# Add a 'Match_Type' column which indicates these are "Highly Likely Potential" matches
# change to descending order by similarity, ascending by account ID
# Out:
#        SFDC_ACCOUNT_ID                                       name_a  \
# 0   0011p00001ft73NAAQ        junior suite 1 king bed with sofa bed
# 1   0011p00002OYDpYAAX                                  double room
# 2   0012400000aAGLxAAO                       deluxe suite 1 bedroom
# 3   0012400000qJfp2AAC            grand corner king room 1 king bed
# 4   0012400001Ow1FQAAZ     king room suite 1 king bed with sofa bed
# 5   0014H00001wABGcQAO  deluxe suite 1 king bed non smoking kitchen
# 6   0011p00001ZrpzsAAB                   room 1 king bed ocean view
# 7   0012400000GGZBZAA5                     deluxe room 2 queen beds
# 8   0012400000l6u0AAAQ           business double room 2 double beds
# 9   0014H000021UEyqQAG     room 2 double beds (19th to 25th floors)
# 10  0014H00002GIJkqQAH         premier room 1 king bed (royal club)
# 11  0012400000nmQr3AAE                      room partial ocean view
# 12  0012400001ImdRYAAZ  club suite 1 king bed accessible ocean view
# 13  0011p00001SLPL1AAP                     standard room ocean view
# 14  0011p00001T6NV6AAN                              room ocean view
# 15  0011p00001Tf9HGAAZ                                  deluxe room
# 16  0011p00001Ti4LkAAJ                                  deluxe room
# 17  0011p00001YEVvfAAH           high floor premium room 1 king bed
# 18  0011p00001anUF3AAM                       deluxe room 1 king bed
# 19  0011p00001dvgKyAAI                       deluxe room 1 king bed
# 20  0011p00002W53XAAAZ                      premier room 1 king bed
# 21  00124000005ievZAAQ                              room ocean view
# 22  0012400000gmLjVAAU                    standard room lagoon view
# 23  0012400000qIKr5AAG                       deluxe room 1 king bed
# 24  0012400000vZcUxAAK                    suite 1 king bed (parlor)
# 25  00124000019HHXlAAO                          city room city view
# 26  0014H000021VF0FQAW                       deluxe room 1 king bed
# 27  0014H00002GHEvcQAH                      classic room 1 king bed
#
#                                               match_b  similarity
# 0                                        junior suite          90
# 1           business double room with two double beds          90
# 2                           deluxe one  bedroom suite          90
# 3                              grand corner king room          90
# 4                                           king room          90
# 5                                        deluxe suite          90
# 6                       ocean view room with king bed          91
# 7                         deluxe room  two queen beds          91
# 8           business double room with two double beds          91
# 9   two double beds  location room (19th to 25th f...          92
# 10              royal club premier room  one king bed          92
# 11                           partical ocean view room          93
# 12  accessible club ocean view suite with one king...          93
# 13                standard room with ocean front view          95
# 14                               room with ocean view          95
# 15                                   deluxe king room          95
# 16                                   deluxe king room          95
# 17                       high floor premium king room          95
# 18                                   deluxe king room          95
# 19                                   deluxe king room          95
# 20                                  premier king room          95
# 21                               room with ocean view          95
# 22                  standard room dolphin lagoon view          95
# 23                                   deluxe king room          95
# 24                                  king parlor suite          95
# 25                          queen room with city view          95
# 26                                   deluxe king room          95
# 27                                  classic king room          95

# %%
# Results Table: 80-90% similarity
final_result_80 = a_test_df[(a_test_df.similarity < 90) & (a_test_df.similarity > 79)]
final_result_80 = final_result_80.sort_values(by=['similarity']).reset_index(drop=True)
final_result_80

## TODO ##
# Add a 'Match_Type' column which indicates these are "Likely Potential" matches
# change to descending order by similarity, ascending by account ID
# Out:
#        SFDC_ACCOUNT_ID                                             name_a  \
# 0   0012400000jqfYCAAY                           business plan 1 king bed
# 1   0014H00002WncdmQAB                          room 1 king bed pool view
# 2   0011p00001ZrpzsAAB                 room 1 king bed resort view (alii)
# 3   0011p00002OYDJAAA5                                   room 1 queen bed
# 4   0014H00002O27MAQAZ                room 1 queen bed accessible bathtub
# 5   00124000015GfohAAC                         room 1 queen bed city view
# 6   0012400000BFtEaAAL       room 1 queen bed non smoking (fairmont room)
# 7   0012400001Ow1FQAAZ                                 room 2 double beds
# 8   0012400000YdK0fAAF                       room 2 double beds city view
# 9   0014H00002O21tyQAB                     room 2 double beds non smoking
# 10  0012400000DjkTTAAZ       room 2 double beds ocean view (diamond head)
# 11  0012400000hYg3gAAC              room 2 double beds partial ocean view
# 12  0012400001HLH75AAH                   room 2 queen beds (waikiki view)
# 13  0012400000qI3m4AAC                        room 2 queen beds city view
# 14  0014H00002f7uyRQAQ                      room 2 queen beds garden view
# 15  001b000000X0SDdAAN                                    room accessible
# 16  0012400001Ime60AAB                                    room oceanfront
# 17  0011p00002JYCVwAAP                          signature room 1 king bed
# 18  0012400001HL0SBAA1              signature room 1 king bed non smoking
# 19  0014H00001n9LNlQAM           signature room 2 double beds non smoking
# 20  0014H00002GHKH0QAP                        signature room 2 queen beds
# 21  0014H00002nCqWCQA0                          signature suite 1 bedroom
# 22  0012400000qJfleAAC                standard room 1 king bed accessible
# 23  00124000006xDGHAA2  standard room mountain view (city view  kona t...
# 24  0011p00002Tk1IEAAZ  standard room ocean view (waikiki tower)  no r...
# 25  0012400001E0y8YAAR                           standard room oceanfront
# 26  0012400001AkoSMAAZ  standard room partial ocean view (kona tower) ...
# 27  001b000000gqJ6WAAU  standard room partial ocean view (waikiki towe...
# 28  0014H00002O18ZaQAJ             studio 1 king bed with sofa bed corner
# 29  0012400000BFtEaAAL                       suite 1 king bed non smoking
# ..                 ...                                                ...
# 40  0011p00002OVe50AAD  club room lake view (club lounge access for 2 ...
# 41  0011p00002JZFezAAH                     club room premium 2 queen beds
# 42  0012400001ImdRYAAZ  club suite 1 king bed oceanfront (no resort ch...
# 43  0014H000021WJ5aQAG                 deluxe room 1 king bed non smoking
# 44  0011p00002TiPwlAAF               deluxe room 1 queen bed (high floor)
# 45  0014H00002GI0dxQAD                              deluxe room city view
# 46  0012400001ImfcbAAB                                 deluxe room corner
# 47  0014H00002O28rOQAR              room 1 king bed non smoking (leisure)
# 48  0012400000UEiZaAAL              executive room 1 king bed non smoking
# 49  0011p00001RNC8VAAX                              deluxe room lake view
# 50  0012400000G5L0UAAV                 luxury room 1 king bed non smoking
# 51  0011p00001ZrpzsAAB  room 1 king bed accessible view (rainbow bathtub)
# 52  0011p00001ZrpzsAAB  room 1 king bed accessible resort view (alii b...
# 53  0012400000J4kLeAAJ                         room 1 king bed accessible
# 54  0012400000hXEzjAAG                                    room 1 king bed
# 55  0014H000021W95HQAS                                    room 1 king bed
# 56  0012400001HL0SBAA1         fairmont gold suite 1 king bed non smoking
# 57  0014H00002GI0fFQAT                          premium room 2 queen beds
# 58  0014H00001wCXjhQAG                        traditional room 1 king bed
# 59  0012400000bP5g1AAC                            premium room 1 king bed
# 60  0011p0000209iN1AAI                luxury room 2 queen beds (prestige)
# 61  0012400000cZUWIAA4              luxury room 2 double beds non smoking
# 62  0012400000sgcG1AAI                luxury room 1 queen bed non smoking
# 63  0014H000021UIiMQAW                           premium room 1 queen bed
# 64  0012400000cWCIHAA4   room 2 double beds accessible partial ocean view
# 65  0011p00001ivel0AAA                room 1 king bed (19th to 25 floors)
# 66  0012400000Q3PLwAAN               standard room mountain view (scenic)
# 67  0011p00002W53XAAAZ                                  premier twin room
# 68  0014H00002GIfIlQAL                                    suite 1 bedroom
# 69  0014H000021VzwBQAS                                    suite 1 bedroom
#
#                                               match_b  similarity
# 0   accessible club ocean view suite with one king...          86
# 1   accessible club ocean view suite with one king...          86
# 2   accessible club ocean view suite with one king...          86
# 3   accessible club ocean view suite with one king...          86
# 4   alii tower resort view with king bed  mobility...          86
# 5   accessible club ocean view suite with one king...          86
# 6                                  business king room          86
# 7   accessible partial ocean view with two double ...          86
# 8   accessible club ocean view suite with one king...          86
# 9   accessible partial ocean view with two double ...          86
# 10                                 business king room          86
# 11  accessible partial ocean view with two double ...          86
# 12  accessible club ocean view suite with one king...          86
# 13  accessible club ocean view suite with one king...          86
# 14  accessible club ocean view suite with one king...          86
# 15  accessible club ocean view suite with one king...          86
# 16          business double room with two double beds          86
# 17  accessible club ocean view suite with one king...          86
# 18  alii tower resort view with king bed  mobility...          86
# 19                                 business king room          86
# 20  accessible partial ocean view with two double ...          86
# 21  accessible club ocean view suite with one king...          86
# 22  alii tower resort view with king bed  mobility...          86
# 23               alii tower resort view with king bed          86
# 24               alii tower resort view with king bed          86
# 25          business double room with two double beds          86
# 26               alii tower resort view with king bed          86
# 27               alii tower resort view with king bed          86
# 28  alii tower resort view with king bed  mobility...          86
# 29  accessible club ocean view suite with one king...          86
# ..                                                ...         ...
# 40                                 business king room          86
# 41  accessible club ocean view suite with one king...          86
# 42                                 business king room          86
# 43  alii tower resort view with king bed  mobility...          86
# 44  alii tower resort view with king bed  mobility...          86
# 45  accessible club ocean view suite with one king...          86
# 46          business double room with two double beds          86
# 47  alii tower resort view with king bed  mobility...          86
# 48  alii tower resort view with king bed  mobility...          86
# 49  accessible club ocean view suite with one king...          86
# 50  alii tower resort view with king bed  mobility...          86
# 51                                 business king room          86
# 52                                 business king room          86
# 53  accessible club ocean view suite with one king...          86
# 54  accessible club ocean view suite with one king...          86
# 55  accessible club ocean view suite with one king...          86
# 56                                 business king room          86
# 57  accessible partial ocean view with two double ...          86
# 58  accessible club ocean view suite with one king...          86
# 59  accessible club ocean view suite with one king...          86
# 60                                 business king room          86
# 61                                 business king room          86
# 62  alii tower resort view with king bed  mobility...          86
# 63  accessible club ocean view suite with one king...          86
# 64  accessible partial ocean view with two double ...          87
# 65      king bed  location room (19th to 25th floors)          87
# 66                   standard room with mountain view          87
# 67                                  premier king room          88
# 68                                 one  bedroom suite          88
# 69                                 one  bedroom suite          88
#
# [70 rows x 4 columns]

# %%
# Results Tables - low or no similarity
final_result_low_similarity = a_test_df[(a_test_df.similarity < 80) ]
final_result_low_similarity = final_result_low_similarity.sort_values(by=['similarity']).reset_index(drop=True)
final_result_low_similarity

## TODO ##
# Add a 'Match_Type' column which indicates these are "Not Likely Potential" matches
# Out:
# Empty DataFrame
# Columns: [SFDC_ACCOUNT_ID, name_a, match_b, similarity]
# Index: []

# %%
# Expected Output columns same as settlement file
# Same Mandatory files
# And same output structure

# %% [markdown]
# ### Method 4: [DO NOT USE!]
# * Use a find match function and process.extractOne
# * Like this methods THE LEAST
# * https://stackoverflow.com/questions/53103848/fuzzy-matching-two-columns-in-the-same-dataframe-using-python
#
#
# #### Problem: AGAIN low performance
# Work fine for two files with 100 rows
# Works horribly for two files with 5k rows!
# Do not like the output - it's not intuitive

# %%
#import pandas as pd
#from fuzzywuzzy import process, fuzz

name_list = b_test_df['name_b']

def find_match(x):

    match = process.extractOne(x['name_a'], name_list, scorer=fuzz.ratio)
    return pd.Series([match[0], match[1]])

a_test_df[['match','match_rating']] = a_test_df.apply(find_match, axis=1, result_type='expand')
a_test_df[['match','match_rating']]

# %% [markdown]
# ### METHOD 5
# * Fuzzy Merge Function to produce desired output
# * works pretty well and produces a good output
# * not tested on larger data sets yet
# https://stackoverflow.com/questions/13636848/is-it-possible-to-do-fuzzy-match-merge-with-python-pandas

# %%
def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=2):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].tolist()

    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m

    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2

    return df_1

# %%
fuzzy_merge(a_test_df, b_test_df, 'name_a', 'name_b', threshold=80)
# Out:
#         SFDC_ACCOUNT_ID                                             name_a  \
# 0    0012400000l6u0AAAQ                 business double room 2 double beds
# 1    0012400000jqfYCAAY                           business plan 1 king bed
# 2    00124000019HHXlAAO                                city room city view
# 3    0014H00002GHEvcQAH                            classic room 1 king bed
# 4    00124000008FHqrAAG                               club room 1 king bed
# 5    0011p00002JYCDNAA5                               club room 1 king bed
# 6    0011p0000265zAlAAI                    club room 1 king bed oceanfront
# 7    0012400001HOFKEAA5                             club room 2 queen beds
# 8    0011p00001dvdacAAA                             club room 2 queen beds
# 9    0012400000bjZrqAAE  club room city view (club lounge access for 2 ...
# 10   0011p00002OVe50AAD  club room lake view (club lounge access for 2 ...
# 11   0011p00002JZFezAAH                     club room premium 2 queen beds
# 12   0012400001ImdRYAAZ        club suite 1 king bed accessible ocean view
# 13   0012400001ImdRYAAZ  club suite 1 king bed oceanfront (no resort ch...
# 14   0011p00001Tf9HGAAZ                                        deluxe room
# 15   0011p00001Ti4LkAAJ                                        deluxe room
# 16   0011p00001anUF3AAM                             deluxe room 1 king bed
# 17   0011p00001dvgKyAAI                             deluxe room 1 king bed
# 18   0014H000021VF0FQAW                             deluxe room 1 king bed
# 19   0012400000qIKr5AAG                             deluxe room 1 king bed
# 20   0014H000021WJ5aQAG                 deluxe room 1 king bed non smoking
# 21   0011p00002TiPwlAAF               deluxe room 1 queen bed (high floor)
# 22   0012400000GGZBZAA5                           deluxe room 2 queen beds
# 23   0014H00002GI0dxQAD                              deluxe room city view
# 24   0012400001ImfcbAAB                                 deluxe room corner
# 25   0011p00001RNC8VAAX                              deluxe room lake view
# 26   0014H000021VWCKQA4                                       deluxe suite
# 27   0012400000aAGLxAAO                             deluxe suite 1 bedroom
# 28   0014H00001wABGcQAO        deluxe suite 1 king bed non smoking kitchen
# 29   0011p00002OYDpYAAX                                        double room
# ..                  ...                                                ...
# 71   0012400000hYg3gAAC              room 2 double beds partial ocean view
# 72   0012400001HLH75AAH                   room 2 queen beds (waikiki view)
# 73   0012400000qI3m4AAC                        room 2 queen beds city view
# 74   0014H00002f7uyRQAQ                      room 2 queen beds garden view
# 75   001b000000X0SDdAAN                                    room accessible
# 76   00124000005ievZAAQ                                    room ocean view
# 77   0011p00001T6NV6AAN                                    room ocean view
# 78   0012400001Ime60AAB                                    room oceanfront
# 79   0012400000nmQr3AAE                            room partial ocean view
# 80   0011p00002JYCVwAAP                          signature room 1 king bed
# 81   0012400001HL0SBAA1              signature room 1 king bed non smoking
# 82   0014H00001n9LNlQAM           signature room 2 double beds non smoking
# 83   0014H00002GHKH0QAP                        signature room 2 queen beds
# 84   0014H00002nCqWCQA0                          signature suite 1 bedroom
# 85   0012400000qJfleAAC                standard room 1 king bed accessible
# 86   0012400000gmLjVAAU                          standard room lagoon view
# 87   00124000006xDGHAA2  standard room mountain view (city view  kona t...
# 88   0012400000Q3PLwAAN               standard room mountain view (scenic)
# 89   0011p00001SLPL1AAP                           standard room ocean view
# 90   0011p00002Tk1IEAAZ  standard room ocean view (waikiki tower)  no r...
# 91   0012400001E0y8YAAR                           standard room oceanfront
# 92   0012400001AkoSMAAZ  standard room partial ocean view (kona tower) ...
# 93   001b000000gqJ6WAAU  standard room partial ocean view (waikiki towe...
# 94   0014H00002O18ZaQAJ             studio 1 king bed with sofa bed corner
# 95   0014H00002GIfIlQAL                                    suite 1 bedroom
# 96   0014H000021VzwBQAS                                    suite 1 bedroom
# 97   0012400000vZcUxAAK                          suite 1 king bed (parlor)
# 98   0012400000BFtEaAAL                       suite 1 king bed non smoking
# 99   0012400001Ko0VnAAJ              traditional double room 2 double beds
# 100  0014H00001wCXjhQAG                        traditional room 1 king bed
#
#                                                match_b  similarity  \
# 0            business double room with two double beds          91
# 1    accessible club ocean view suite with one king...          86
# 2                            queen room with city view          95
# 3                                    classic king room          95
# 4    accessible club ocean view suite with one king...          86
# 5    accessible club ocean view suite with one king...          86
# 6    accessible club ocean view suite with one king...          86
# 7    accessible club ocean view suite with one king...          86
# 8    accessible club ocean view suite with one king...          86
# 9                                   business king room          86
# 10                                  business king room          86
# 11   accessible club ocean view suite with one king...          86
# 12   accessible club ocean view suite with one king...          93
# 13                                  business king room          86
# 14                                    deluxe king room          95
# 15                                    deluxe king room          95
# 16                                    deluxe king room          95
# 17                                    deluxe king room          95
# 18                                    deluxe king room          95
# 19                                    deluxe king room          95
# 20   alii tower resort view with king bed  mobility...          86
# 21   alii tower resort view with king bed  mobility...          86
# 22                         deluxe room  two queen beds          91
# 23   accessible club ocean view suite with one king...          86
# 24           business double room with two double beds          86
# 25   accessible club ocean view suite with one king...          86
# 26                                        deluxe suite         100
# 27                           deluxe one  bedroom suite          90
# 28                                        deluxe suite          90
# 29           business double room with two double beds          90
# ..                                                 ...         ...
# 71   accessible partial ocean view with two double ...          86
# 72   accessible club ocean view suite with one king...          86
# 73   accessible club ocean view suite with one king...          86
# 74   accessible club ocean view suite with one king...          86
# 75   accessible club ocean view suite with one king...          86
# 76                                room with ocean view          95
# 77                                room with ocean view          95
# 78           business double room with two double beds          86
# 79                            partical ocean view room          93
# 80   accessible club ocean view suite with one king...          86
# 81   alii tower resort view with king bed  mobility...          86
# 82                                  business king room          86
# 83   accessible partial ocean view with two double ...          86
# 84   accessible club ocean view suite with one king...          86
# 85   alii tower resort view with king bed  mobility...          86
# 86                   standard room dolphin lagoon view          95
# 87                alii tower resort view with king bed          86
# 88                    standard room with mountain view          87
# 89                 standard room with ocean front view          95
# 90                alii tower resort view with king bed          86
# 91           business double room with two double beds          86
# 92                alii tower resort view with king bed          86
# 93                alii tower resort view with king bed          86
# 94   alii tower resort view with king bed  mobility...          86
# 95                                  one  bedroom suite          88
# 96                                  one  bedroom suite          88
# 97                                   king parlor suite          95
# 98   accessible club ocean view suite with one king...          86
# 99                                  business king room          86
# 100  accessible club ocean view suite with one king...          86
#
#                                                matches
# 0    business double room with two double beds, bus...
# 1    accessible club ocean view suite with one king...
# 2       queen room with city view, room with city view
# 3    classic king room, accessible club ocean view ...
# 4    accessible club ocean view suite with one king...
# 5    accessible club ocean view suite with one king...
# 6    accessible club ocean view suite with one king...
# 7    accessible club ocean view suite with one king...
# 8    accessible club ocean view suite with one king...
# 9      business king room, city view with one king bed
# 10     business king room, city view with one king bed
# 11   accessible club ocean view suite with one king...
# 12   accessible club ocean view suite with one king...
# 13     business king room, city view with one king bed
# 14                  deluxe king room, deluxe king room
# 15                  deluxe king room, deluxe king room
# 16                  deluxe king room, deluxe king room
# 17                  deluxe king room, deluxe king room
# 18                  deluxe king room, deluxe king room
# 19                  deluxe king room, deluxe king room
# 20   alii tower resort view with king bed  mobility...
# 21   alii tower resort view with king bed  mobility...
# 22   deluxe room  two queen beds, accessible partia...
# 23   accessible club ocean view suite with one king...
# 24   business double room with two double beds, bus...
# 25   accessible club ocean view suite with one king...
# 26   deluxe suite, accessible club ocean view suite...
# 27             deluxe one  bedroom suite, deluxe suite
# 28                    deluxe suite, business king room
# 29   business double room with two double beds, del...
# ..                                                 ...
# 71   accessible partial ocean view with two double ...
# 72   accessible club ocean view suite with one king...
# 73   accessible club ocean view suite with one king...
# 74   accessible club ocean view suite with one king...
# 75   accessible club ocean view suite with one king...
# 76   room with ocean view, accessible club ocean vi...
# 77   room with ocean view, accessible club ocean vi...
# 78   business double room with two double beds, bus...
# 79   partical ocean view room, accessible club ocea...
# 80   accessible club ocean view suite with one king...
# 81   alii tower resort view with king bed  mobility...
# 82               business king room, classic king room
# 83   accessible partial ocean view with two double ...
# 84   accessible club ocean view suite with one king...
# 85   alii tower resort view with king bed  mobility...
# 86   standard room dolphin lagoon view, accessible ...
# 87   alii tower resort view with king bed, business...
# 88   standard room with mountain view, alii tower r...
# 89   standard room with ocean front view, standard ...
# 90   alii tower resort view with king bed, business...
# 91   business double room with two double beds, bus...
# 92   alii tower resort view with king bed, business...
# 93   alii tower resort view with king bed, business...
# 94   alii tower resort view with king bed  mobility...
# 95               one  bedroom suite, one bedroom suite
# 96               one  bedroom suite, one bedroom suite
# 97   king parlor suite, accessible club ocean view ...
# 98   accessible club ocean view suite with one king...
# 99   business king room, business king room  exclus...
# 100  accessible club ocean view suite with one king...
#
# [101 rows x 5 columns]

# %% [markdown]
# # Conclusions
# Of the 5 methods tested, some were a better fir for our needs, and some were either a very poor fit or took a very long time to run.
#
# Method 2 and Method 4 had quite low performance on the original data set, and 4 produces a large output that isn't easy to deal with.
# Method 1 is a bit too simplistic.
#
# The recommended methods would be 3 (although not on a large data set) or 5 if you know the threshold for matching that you wish to use.
